# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv(r'204_19_7(preprocessed).csv')
df_depth = df['true depth']
df = df.iloc[:,:15]
df = (df - df.min()) / (df.max() - df.min())
df['true depth'] = df_depth
# df = df.apply(pd.to_numeric, errors='ignore')
# columns_to_normalize = df.columns.difference(['true depth'])
# numeric_columns = df[columns_to_normalize].select_dtypes(include=[float, int]).columns
# scaler = MinMaxScaler()
# df[numeric_columns] = scaler.fit_transform(df[numeric_columns])

# %%
for column in df.columns:
    sns.relplot(x="true depth", y=column, data=df, kind="scatter")
# Out:
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ...

# %%
#plt.figure(figsize=(100, 1))
for column in df.columns:
    #sns.relplot(x="true depth", y=column, data=df, kind="scatter")
    if column != 'true depth':
        plt.scatter(df['true depth'],df[column])
plt.xlim(2120, 2200)
# plt.xlim(2155, 2160)
# plt.xlim(2540, 2545)
# Out:
# (2120.0, 2200.0)

# %%
sns.pairplot(df, kind='scatter', diag_kind='kde')
# Out:
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
